# %% [markdown]
# # Анализ продаж
# ---

# %% [markdown]
# ## Импорт необходимых модулей
# 1. импорт os для получения списка всех файлов каталога.
# 2. импорт numpy для математических операций над массивами и фреймами данных.
# 3. импорт pandas для чтения данных и работы с ними.
# 4. импорт matplotlib для визуализации наборов данных.
# 5. импорт warnings для получения предупреждающих сообщений, которые часто появляются в DataFrame.

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
import requests
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Объединение данных о продажах за 12 месяцев в один файл csv

# %%
x=pd.read_csv("Sales_Data\\Sales_April_2019.csv")
file=[ i for i in os.listdir("Sales_Data")]
y=pd.DataFrame()
for j in file:
    x=pd.read_csv("Sales_Data\\"+j)
    y=pd.concat([y,x])
    
y.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %% [markdown]
# ### Сохранение данных в новый csv-файл

# %%
y.to_csv("Updated_sales.csv",index=False)

# %% [markdown]
# ## Чтение обновленного датасета и проверка на NaN, типы данных и статистический анализ
#
# 1. Обновленный датасет находится в виде csv-файла, и для загрузки обновленных данных необходимо использовать pandas read_csv.
# 2. После загрузки важно проверить полную информацию о данных, так как она может содержать много скрытой информации, например, нулевые значения в столбце или строке.
# 3. Проверьте, есть ли нулевые значения. Если они есть, то можно выполнить следующие действия,
#     1. Заполнение NaN-значений средним, медианой и модой с помощью метода fillna().
#     2. Отбросить значения NaN
# 4. Описать данные --> что может дать статистический анализ

# %%
df=pd.read_csv("Updated_sales.csv")
df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1           NaN                         NaN              NaN        NaN
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %% [markdown]
# ### Пропустить пустую строку

# %%
df=pd.read_csv('Updated_sales.csv',skiprows=[2])
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1   176559  Bose SoundSport Headphones                1      99.99
# 2   176560                Google Phone                1        600
# 3   176560            Wired Headphones                1      11.99
# 4   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186849 entries, 0 to 186848
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
# dtypes: object(6)
# memory usage: 8.6+ MB

# %%
df.isnull().sum()
# Out:
# Order ID            544
# Product             544
# Quantity Ordered    544
# Price Each          544
# Order Date          544
# Purchase Address    544
# dtype: int64

# %%
df.describe()
# Out:
#         Order ID               Product Quantity Ordered Price Each  \
# count     186305                186305           186305     186305
# unique    178438                    20               10         24
# top     Order ID  USB-C Charging Cable                1      11.95
# freq         355                 21903           168552      21903
#
#         Order Date  Purchase Address
# count       186305            186305
# unique      142396            140788
# top     Order Date  Purchase Address
# freq           355               355

# %% [markdown]
# ### Проверка нулевых значений в строках

# %%
df_nan=df[df.isnull().any(axis=1)]
df_nan
# Out:
#        Order ID Product Quantity Ordered Price Each Order Date  \
# 355         NaN     NaN              NaN        NaN        NaN
# 734         NaN     NaN              NaN        NaN        NaN
# 1432        NaN     NaN              NaN        NaN        NaN
# 1552        NaN     NaN              NaN        NaN        NaN
# 1570        NaN     NaN              NaN        NaN        NaN
# ...         ...     ...              ...        ...        ...
# 185175      NaN     NaN              NaN        NaN        NaN
# 185437      NaN     NaN              NaN        NaN        NaN
# 186041      NaN     NaN              NaN        NaN        NaN
# 186547      NaN     NaN              NaN        NaN        NaN
# 186825      NaN     NaN              NaN        NaN        NaN
#
#        Purchase Address
# 355                 NaN
# 734                 NaN
# 1432                NaN
# 1552                NaN
# 1570                NaN
# ...                 ...
# 185175              NaN
# ...

# %% [markdown]
# ### Отбросить все строки с нулевым значением

# %%
df=df.dropna(how="all")
df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1        176559  Bose SoundSport Headphones                1      99.99
# 2        176560                Google Phone                1        600
# 3        176560            Wired Headphones                1      11.99
# 4        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186844   259353      AAA Batteries (4-pack)                3       2.99
# 186845   259354                      iPhone                1        700
# 186846   259355                      iPhone                1        700
# 186847   259356      34in Ultrawide Monitor                1     379.99
# 186848   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
df.isnull().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %% [markdown]
# ### Поиск Or и его удаление
# т.к. встречаются строки с заголовками из-за объединения файлов

# %%
temp_df=df[df["Order Date"].str[0:2]=='Or']
temp_df
# Out:
#         Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 518     Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1148    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1154    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 2877    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 2892    Order ID  Product  Quantity Ordered  Price Each  Order Date
# ...          ...      ...               ...         ...         ...
# 185163  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 185550  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 186562  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 186631  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 186737  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#         Purchase Address
# 518     Purchase Address
# 1148    Purchase Address
# 1154    Purchase Address
# 2877    Purchase Address
# ...

# %% [markdown]
# ### Избавление от текста в столбце даты заказа

# %%
df=df[df["Order Date"].str[0:2]!='Or']
df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1        176559  Bose SoundSport Headphones                1      99.99
# 2        176560                Google Phone                1        600
# 3        176560            Wired Headphones                1      11.99
# 4        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186844   259353      AAA Batteries (4-pack)                3       2.99
# 186845   259354                      iPhone                1        700
# 186846   259355                      iPhone                1        700
# 186847   259356      34in Ultrawide Monitor                1     379.99
# 186848   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
df['Order Date'].value_counts().unique().sum()
# Out:
# 36

# %% [markdown]
# ### Добавление столбца месяца

# %%
df['Month'] = pd.to_datetime(df['Order Date']).dt.month
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1   176559  Bose SoundSport Headphones                1      99.99
# 2   176560                Google Phone                1        600
# 3   176560            Wired Headphones                1      11.99
# 4   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address  Month
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 4  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4

# %% [markdown]
# ### Установка правильного типа колонок

# %%
df["Quantity Ordered"]=pd.to_numeric(df["Quantity Ordered"]) #Меняю на int
df["Price Each"]=pd.to_numeric(df["Price Each"]) #Меняю на float
df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 1        176559  Bose SoundSport Headphones                 1       99.99
# 2        176560                Google Phone                 1      600.00
# 3        176560            Wired Headphones                 1       11.99
# 4        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186844   259353      AAA Batteries (4-pack)                 3        2.99
# 186845   259354                      iPhone                 1      700.00
# 186846   259355                      iPhone                 1      700.00
# 186847   259356      34in Ultrawide Monitor                 1      379.99
# 186848   259357        USB-C Charging Cable                 1       11.95
#
#             Order Date                         Purchase Address  Month
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185950 entries, 0 to 186848
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  object
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  int64
#  3   Price Each        185950 non-null  float64
#  4   Order Date        185950 non-null  object
#  5   Purchase Address  185950 non-null  object
#  6   Month             185950 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 11.3+ MB

# %%
df.describe()
# Out:
#        Quantity Ordered     Price Each          Month
# count     185950.000000  185950.000000  185950.000000
# mean           1.124383     184.399735       7.059140
# std            0.442793     332.731330       3.502996
# min            1.000000       2.990000       1.000000
# 25%            1.000000      11.950000       4.000000
# 50%            1.000000      14.950000       7.000000
# 75%            1.000000     150.000000      10.000000
# max            9.000000    1700.000000      12.000000

# %%
def get_exchange_rate():
    # Запрашиваем текущий курс валют с использованием API
    url = 'https://api.exchangeratesapi.io/latest'
    params = {'base': 'USD', 'symbols': 'RUB'}
    
    try:
        response = requests.get(url, params=params)
        data = response.json()
        exchange_rate = data['rates']['RUB']
        return exchange_rate
    except requests.exceptions.RequestException as e:
        print(f"Ошибка при получении курса валют: {e}")
        return None
    
    
rate = get_exchange_rate()

if rate is not None:
    df["Price Each"] = df["Price Each"].apply(lambda x: x*rate)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [19], line 16
#      12         print(f"Ошибка при получении курса валют: {e}")
#      13         return None
# ---> 16 rate = get_exchange_rate()
#      18 if rate is not None:
#      19     df["Price Each"] = df["Price Each"].apply(lambda x: x*rate)
#
# Cell In [19], line 9, in get_exchange_rate()
#       7     response = requests.get(url, params=params)
#       8     data = response.json()
# ----> 9     exchange_rate = data['rates']['RUB']
#      10     return exchange_rate
#      11 except requests.exceptions.RequestException as e:
#
# KeyError: 'rates'

# %% [markdown]
# ## В какое время следует показывать рекламу, чтобы максимально увеличить вероятность покупки товара покупателем?

# %%
df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 1        176559  Bose SoundSport Headphones                 1       99.99
# 2        176560                Google Phone                 1      600.00
# 3        176560            Wired Headphones                 1       11.99
# 4        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186844   259353      AAA Batteries (4-pack)                 3        2.99
# 186845   259354                      iPhone                 1      700.00
# 186846   259355                      iPhone                 1      700.00
# 186847   259356      34in Ultrawide Monitor                 1      379.99
# 186848   259357        USB-C Charging Cable                 1       11.95
#
#             Order Date                         Purchase Address  Month
# ...

# %% [markdown]
# ### Преобразование даты заказа в datetime

# %%
df["Order Date"]=pd.to_datetime(df["Order Date"])

# %% [markdown]
# ### Добавление столбца Hours (часы)

# %%
df["Hours"]=df["Order Date"].dt.hour
df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 1        176559  Bose SoundSport Headphones                 1       99.99
# 2        176560                Google Phone                 1      600.00
# 3        176560            Wired Headphones                 1       11.99
# 4        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186844   259353      AAA Batteries (4-pack)                 3        2.99
# 186845   259354                      iPhone                 1      700.00
# 186846   259355                      iPhone                 1      700.00
# 186847   259356      34in Ultrawide Monitor                 1      379.99
# 186848   259357        USB-C Charging Cable                 1       11.95
#
#                 Order Date                         Purchase Address  Month  \
# ...

# %%
df.groupby(['Hours']).sum()
# Out:
#        Quantity Ordered  Price Each  Month
# Hours
# 0                  4428   709296.70  27554
# 1                  2619   458490.00  16657
# 2                  1398   233833.64   8507
# 3                   928   144726.42   5904
# 4                   937   162058.18   6148
# 5                  1493   229621.21   9301
# 6                  2810   445000.11  17539
# 7                  4556   740568.11  28850
# 8                  7002  1185970.62  43626
# 9                  9816  1628498.49  60981
# 10                12308  1932665.62  76928
# 11                14005  2288855.18  87654
# 12                14202  2299876.68  89161
# 13                13685  2139743.86  85808
# 14                12362  2072194.77  77836
# 15                11391  1931174.99  72060
# 16                11662  1892454.54  72939
# 17                12229  2116777.02  77454
# 18                13802  2207696.93  86421
# 19                14470  2398588.31  91389
# 20                13768  2268185.16  86375
# ...

# %%
df.groupby(['Hours']).count()
# Out:
#        Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# Hours
# 0          3910     3910              3910        3910        3910
# 1          2350     2350              2350        2350        2350
# 2          1243     1243              1243        1243        1243
# 3           831      831               831         831         831
# 4           854      854               854         854         854
# 5          1321     1321              1321        1321        1321
# 6          2482     2482              2482        2482        2482
# 7          4011     4011              4011        4011        4011
# 8          6256     6256              6256        6256        6256
# 9          8748     8748              8748        8748        8748
# 10        10944    10944             10944       10944       10944
# 11        12411    12411             12411       12411       12411
# 12        12587    12587             12587       12587       12587
# ...

# %%
plt.title("График времени")
times=[time for time,df in df.groupby(["Hours"])]
plt.plot(times,df.groupby(["Hours"]).count(), "black")
plt.xticks(times)
plt.xlabel("Часы")
plt.ylabel("US $")
plt.grid()
plt.show()

# %%
plt.title("График месяцев")
month=[month for month,df in df.groupby(["Month"])]
plt.plot(month,df.groupby(["Month"]).count(), "black")
plt.xticks(month)
plt.xlabel("Месяц")
plt.ylabel("US $")
plt.grid()
plt.show()

# %% [markdown]
# #### По этой линейной диаграмме я рекомендую показывать рекламу чуть раньше 11 или 19 часов в апереле, ноябре или декабре

# %%
df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 1        176559  Bose SoundSport Headphones                 1       99.99
# 2        176560                Google Phone                 1      600.00
# 3        176560            Wired Headphones                 1       11.99
# 4        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186844   259353      AAA Batteries (4-pack)                 3        2.99
# 186845   259354                      iPhone                 1      700.00
# 186846   259355                      iPhone                 1      700.00
# 186847   259356      34in Ultrawide Monitor                 1      379.99
# 186848   259357        USB-C Charging Cable                 1       11.95
#
#                 Order Date                         Purchase Address  Month  \
# ...
